# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZonairaTariq/flyrank-AI-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
## My Lane as an ML Task

#I chose the **Refresh / Content Opportunity Scoring** lane. This is a **scoring** task because the goal is to assign a priority score to webpages so the content team can decide which pages should be refreshed first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# The target is a content refresh priority score for each webpage. Since the starter dataset does not contain a direct refresh score, I will use the observed page performance signals, such as trend direction and other search metrics, as a proxy to identify pages that may need attention.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# I will use **Precision@50** as the success metric. A good result means that most of the top-ranked pages are actually good candidates for a content refresh, making the recommendations more useful.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# One row = one webpage
lane_df = df[[
    "impressions_90d",
    "avg_position",
    "ctr",
    "content_age_days",
    "days_since_last_update",
    "trend_direction"
]]

lane_df.head()
# One row in the dataset represents one webpage. Each row contains search performance information that can be used to estimate the page's refresh priority.
# Out:
#    impressions_90d  avg_position   ctr  content_age_days  \
# 0             3803          10.6  0.76               187
# 1            15320          20.3  0.05               445
# 2            12581          36.5  0.09               141
# 3            11751           6.2  0.49               463
# 4            19140          44.0  0.13               263
#
#    days_since_last_update trend_direction
# 0                      20            down
# 1                      25            down
# 2                      20            down
# 3                      22          stable
# 4                      14            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# A fixed rule might only look at one or two conditions, such as impressions or content age. However, page performance depends on several search signals working together. Machine learning can combine these signals to assign a more accurate priority score than a simple if-statement.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
