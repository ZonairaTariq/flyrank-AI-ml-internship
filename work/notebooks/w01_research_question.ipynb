# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZonairaTariq/flyrank-AI-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane (or Freestyle) and Why

#I chose the **Refresh / Content Opportunity Scoring** lane because it focuses on identifying pages that may benefit from a content review. While working through the starter notebooks, I found this problem practical and interesting because it combines search performance data with machine learning to support better content decisions. I would like to explore how different signals can help prioritize pages that need attention.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## The Question

# Decision:  My work aims to help decide which pages should be prioritized for a content refresh.

# Who acts on it?: A content or SEO team can use these recommendations to review and update the selected pages.

# Cost of a wrong recommendation: If the recommendation is wrong, important pages may be missed while time and effort could be spent refreshing pages that do not actually need attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Quick Look at the Data

# I explored the starter dataset to understand whether this lane is worth investigating. I found that the correlation between search volume and impressions is **0.001**, which suggests that search volume alone is not enough to explain page traffic. I also observed that the average CTR decreases from **0.3548** for Page 1 results to **0.0554** for deep-ranking pages. These observations suggest that multiple search signals should be considered when deciding which pages may benefit from a content refresh, making this lane worth exploring over the next several weeks.

corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation (search_volume vs impressions_90d): {corr:.3f}")

visible = df[df["impressions_90d"] >= 100]
ctr_by_pos = visible.groupby("position_tier")["ctr"].mean().sort_values(ascending=False)

print("\nMean CTR by position tier")
print(ctr_by_pos.round(4))
# Out:
# Correlation (search_volume vs impressions_90d): 0.001
#
# Mean CTR by position tier
# position_tier
# page_1      0.3548
# top_3       0.3341
# striking    0.2558
# page_3_5    0.1424
# deep        0.0554
# Name: ctr, dtype: float64

# %%
# These observations show that multiple search signals should be considered when identifying pages for content refresh. This makes the Refresh / Content Opportunity Scoring lane a good area to explore during the internship.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
## Careful Words

#This work is intended to support decision-making by identifying patterns in the available data. Any findings should be treated as observations rather than proof of cause and effect. The goal is not to predict Google's ranking algorithm, but to provide data-informed recommendations for content review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
